# %% [markdown]
# # Export YOLOv8 to ONNX
#
# 1. Upload your `teeth_seg_final_best.pt` file
# 2. Run the cells below
# 3. Download the generated ONNX file

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Export to ONNX (640x640 for quality - teeth need details!)
YOLO("teeth_seg_final_best.pt").export(format="onnx", imgsz=640, simplify=True)

# %% [markdown]
# Download the generated `.onnx` file and save it as `public/models/teeth-detection-seg.onnx`
